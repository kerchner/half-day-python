# %% [markdown]
# # Experimenting with Large Language Models in Python
#
# We now have enough Python knowledge to try out a bit of AI!  We can use AI for a wide variety of tasks.
#
# For the purpose of our notebook, you can think of a "pipeline" as something that turns raw text into a model or prediction.
#
# A very popular Python package that provides the functionality to interact with LLMs is the Huggingface `transformers` package.
#
# How would you import the `pipeline` function from the `transformers` package?

# %%
# import the pipeline function from the transformers package here:

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# We're going to use the `pipeline` function, and set the `task` parameter to `'sentiment-analysis'`.  Assign the _result_ to a new variable that we'll call `sentiment_pipeline`.

# %% [markdown]
# #

# %% [markdown]
# Now create a Python list of sentences, and assign it to a variable which we'll call `sentences`.

# %% [markdown]
# #

# %% [markdown]
# To run the `sentences` list through the pipeline, we take our `sentiment_pipeline` pipeline object and pass it `sentences` as the argument.

# %% [markdown]
# ## Text Classification

# %% [markdown]
# Now let's create what's called a zero-shot classification pipeline.
#
# Create an object called `zs_classifier` by calling the `pipeline` constructor with `task='zero-shot-classfication'`.
#
# There's documentation here:  https://huggingface.co/docs/transformers/v5.15.1/en/main_classes/pipelines#transformers.ZeroShotClassificationPipeline

# %% [markdown]
# Call the `zs_classifier` object with the following parameters:
# - `sequences=['This is a Python programming workshop', 'We are at George Washington University']`
# - `candidate_labels=['computer science', 'education', 'politics', 'religion', 'business']`

# %% [markdown]
# ## Text Generation
#
# Now we'd like to use an LLM to take a prompt and generate a response.  For this we'll give the pipeline a task of `text-generation`.  Call the pipeline `text_generator`

# %% [markdown]
# Now call `text_generator` with whatever text you'd like.  Have fun with it.  The argument is called `text_inputs` (see https://huggingface.co/docs/transformers/v5.15.1/en/main_classes/pipelines#transformers.TextGenerationPipeline)

# %% [markdown]
# You might also want to assign the result of calling `text_generator` to a variable, call it `response`.  Use the `print()` function to print the text of the response.  You'll also need to extract it from the list and dictionary that it's embedded in.

# %%
response = text_generator('What is the best way to learn to program in Python?')
print(response[0]["generated_text"])
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[5], line 1
#
# ----> 1 print(response[0]["generated_text"])
#
#
#
# NameError: name 'response' is not defined
